# %%
library(CausalImpact)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-241008f6c129> in <module>
# ----> 1 library(CausalImpact)
#
# NameError: name 'library' is not defined

# %%
mydata <- read.csv(file="~/venv/causalimpact/Septemberalgoupdate/mydata.csv", header=TRUE, sep=",")

# %%
head(mydata)
# Out:
#   twenty19 twenty18
# 1 15501     35200
# 2 39398     58451
# 3 88483    127881
# 4 85092    120615
# 5 81056    113995
# 6 75889    101562

# %%
matplot(mydata, type="l")
# Out:
# plot without title

# %%
dim(mydata)
# Out:
# [1] 214   2

# %%
pre.period <- c(1, 118)

# %%
post.period <- c(119,214)

# %%
impact <- CausalImpact(mydata, pre.period, post.period)

# %%
plot(impact)
# Out:
# Warning message:
# “Removed 214 rows containing missing values (geom_path).”
# Warning message:
# “Removed 428 rows containing missing values (geom_path).”
# plot without title

# %%
summary(impact)
# Out:
# Posterior inference {CausalImpact}
#
#                          Average            Cumulative
# Actual                   88288              8475653
# Prediction (s.d.)        1.1e+05 (3527)     1.0e+07 (338548)
# 95% CI                   [99496, 1.1e+05]   [9551613, 1.1e+07]
#
# Absolute effect (s.d.)   -17998 (3527)      -1727764 (338548)
# 95% CI                   [-25008, -11208]   [-2400769, -1075960]
#
# Relative effect (s.d.)   -17% (3.3%)        -17% (3.3%)
# 95% CI                   [-24%, -11%]       [-24%, -11%]
#
# Posterior tail-area probability p:   0.00101
# Posterior prob. of a causal effect:  99.89899%
#
# For more details, type: summary(impact, "report")

# %%
summary(impact, "report")
# Out:
# Analysis report {CausalImpact}
#
#
# During the post-intervention period, the response variable had an average value of approx. 88.29K. By contrast, in the absence of an intervention, we would have expected an average response of 106.29K. The 95% interval of this counterfactual prediction is [99.50K, 113.30K]. Subtracting this prediction from the observed response yields an estimate of the causal effect the intervention had on the response variable. This effect is -18.00K with a 95% interval of [-25.01K, -11.21K]. For a discussion of the significance of this effect, see below.
#
# Summing up the individual data points during the post-intervention period (which can only sometimes be meaningfully interpreted), the response variable had an overall value of 8.48M. By contrast, had the intervention not taken place, we would have expected a sum of 10.20M. The 95% interval of this prediction is [9.55M, 10.88M].
#
# ...
