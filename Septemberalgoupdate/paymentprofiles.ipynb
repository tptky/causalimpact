# %%
library(CausalImpact)

# %%
mydata <- read.csv(file="~/myprojects/jupyter/causalimpact/paymentprofiles/paymentprofilesdata.csv", header=TRUE, sep=",")

# %%
head(mydata)
# Out:
#   PP  ML   LW
# 1  69  807 112
# 2  43  215  43
# 3  60  326  43
# 4 120  953 215
# 5 103 1073 266
# 6 154 1107 223

# %%
matplot(mydata, type="l")
# Out:
# plot without title

# %%
dim(mydata)
# Out:
# [1] 368   3

# %%
pre.period <- c(1, 281)

# %%
post.period <- c(282,368)

# %%
impact <- CausalImpact(mydata, pre.period, post.period)

# %%
plot(impact)
# Out:
# plot without title

# %%
summary(impact)
# Out:
# Posterior inference {CausalImpact}
#
#                          Average      Cumulative
# Actual                   550          47808
# Prediction (s.d.)        342 (27)     29737 (2367)
# 95% CI                   [287, 394]   [24946, 34320]
#
# Absolute effect (s.d.)   208 (27)     18071 (2367)
# 95% CI                   [155, 263]   [13488, 22862]
#
# Relative effect (s.d.)   61% (8%)     61% (8%)
# 95% CI                   [45%, 77%]   [45%, 77%]
#
# Posterior tail-area probability p:   0.00103
# Posterior prob. of a causal effect:  99.89712%
#
# For more details, type: summary(impact, "report")

# %%
summary(impact, "report")
# Out:
# Analysis report {CausalImpact}
#
#
# During the post-intervention period, the response variable had an average value of approx. 549.52. By contrast, in the absence of an intervention, we would have expected an average response of 341.81. The 95% interval of this counterfactual prediction is [286.74, 394.48]. Subtracting this prediction from the observed response yields an estimate of the causal effect the intervention had on the response variable. This effect is 207.71 with a 95% interval of [155.04, 262.78]. For a discussion of the significance of this effect, see below.
#
# Summing up the individual data points during the post-intervention period (which can only sometimes be meaningfully interpreted), the response variable had an overall value of 47.81K. By contrast, had the intervention not taken place, we would have expected a sum of 29.74K. The 95% interval of this prediction is [24.95K, 34.32K].
#
# ...
